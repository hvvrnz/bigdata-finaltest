# %%
# key = c699f3fbd5bb2b3f9be278dd0fb3e227
import requests

url = "https://dapi.kakao.com/v3/search/book"

header = {"Authorization": "KakaoAK c699f3fbd5bb2b3f9be278dd0fb3e227"}
queryString = {'query': '파이썬', 'page':1, 'size':5}

r = requests.get(url, headers = header, params= queryString)
results = r.json() #json 형식
results
# Out:
# {'documents': [{'authors': ['박응용'],
#    'contents': '개정 2판으로 새롭게 태어났다! 챗GPT를 시작으로 펼쳐진 생성 AI 시대에 맞춰 설명과 예제를 다듬고, 최신 경향과 심화 내용을 보충했다. 또한 이번 개정 2판도 50만 코딩 유튜버인 조코딩과 협업을 통해 유튜브 동영상을 제공해 파이썬을 더 쉽게 공부할 수 있다.  8년 연속 베스트셀러! 위키독스 누적 방문 300만! 독자의 입에서 입으로 전해진 추천과 수많은 대학 및 학원의 교재 채택을 통해 검증은 이미 끝났다. 코딩을 처음 배우는 중고등학생부터 코딩',
#    'datetime': '2023-06-15T00:00:00.000+09:00',
#    'isbn': '1163034738 9791163034735',
#    'price': 22000,
#    'publisher': '이지스퍼블리싱',
#    'sale_price': 19800,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6361131%3Ftimestamp%3D20250709143830',
#    'title': 'Do it! 점프 투 파이썬',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6361131&q=Do+it%21+%EC%A0%90%ED%94%84+%ED%88%AC+%ED%8C%8C%EC%9D%B4%EC%8D%AC'},
#   {'authors': ['윤인성'],
# ...

# %%
r.text
# Out:
# '{"documents":[{"authors":["강지훈 곰다윗 못라니&#40;주란희&#41; 배소현 유다원 이원희 Kim hee soon Opus"],"contents":"억울하게 정지당한 사람이 한둘이 아니었고, 절대 풀어주지 않는다는 얘기를 들었다. 원래 계정을 찾는 것은 포기하고 부계정을 본 계정으로 강제 승급시켰다. 근데 이렇게 정지당하니까 처음엔 화가 많이 났지만, 궁금증도 생겼다. - ‘검색어 | 강지훈’ 중에서  오늘 내가 입고 있는 가장 오래된 옷은 2022년 겨울에 구매한 검은색 패딩 점퍼야. 어느덧 세 번째 겨울을 함께 보내고 있네, 듬성듬성 오리털이 삐져나오지만 찢어지기 전 까지는 계속 입으려 해. 어느새 내","datetime":"2025-02-28T00:00:00.000+09:00","isbn":" 9791167472441","price":17000,"publisher":"하모니북","sale_price":17000,"status":"정상판매","thumbnail":"https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6852810%3Ftimestamp%3D20250404163820","title":"검색어","translators":[],"url":"https://search.daum.net/search?w=bookpage&bookId=6852810&q=%EA%B2%80%EC%83%89%EC%96%B4"},{"authors":["가비 김태연 도니 명진 박효진 봄희 샤이 이원희 장서진 헤오 효찬"],"contents":"하모니북 ‘하루 10분 글쓰기’ 24기 작품집 열다섯 가지 글감으로 쓰인 8명 작가님의 글을 모은 작품집입니다.","datetime":"2025-03-04T00:00:00.000+09:00","isbn":" 9791167472458","price":12000,"publisher":"하모니북
# ...

# %%
results.keys()
# Out:
# dict_keys(['documents', 'meta'])

# %%
meta = results['meta']
meta

# 정보 뽑아서 출력 할 때 출력 할 수 있는 것의 개수가 1000개
# is_end -> 마지막 페이지인 지 묻는 거
# Out:
# {'is_end': False, 'pageable_count': 1000, 'total_count': 4390}

# %%
documents = results['documents']
documents[0]

for item in documents:
    print(f"제목: {item['title']}")
    print(f"저자: {item['authors']}")
    print(f"판매가: {item['sale_price']}:, ")
    print(f"출판사: {item['publisher']}")
    print("-" * 50)
# Out:
# 제목: Do it! 점프 투 파이썬
# 저자: ['박응용']
# 판매가: 19800:,
# 출판사: 이지스퍼블리싱
# --------------------------------------------------
# 제목: 혼자 공부하는 파이썬
# 저자: ['윤인성']
# 판매가: 19800:,
# 출판사: 한빛미디어
# --------------------------------------------------
# 제목: 코딩 자율학습 나도코딩의 파이썬 입문
# 저자: ['나도코딩']
# 판매가: 21600:,
# 출판사: 길벗
# --------------------------------------------------
# 제목: 챗GPT로 만드는 주식 & 암호화폐 자동매매 시스템
# 저자: ['설근민']
# 판매가: 18000:,
# 출판사: 제이펍
# --------------------------------------------------
# 제목: Do it! 점프 투 파이썬
# 저자: ['박응용']
# 판매가: 16920:,
# 출판사: 이지스퍼블리싱
# --------------------------------------------------

# %%
# Kakao 책 검색
# key = c699f3fbd5bb2b3f9be278dd0fb3e227
import requests

url = "https://dapi.kakao.com/v3/search/book"

header = {"Authorization": "KakaoAK c699f3fbd5bb2b3f9be278dd0fb3e227"}
queryString = {'query': '파이썬', 'page':1, 'size':5}

r = requests.get(url, headers = header, params= queryString)
results = r.json() #json 형식

# =================================================================================
print(f"검색개수: {results['meta']['total_count']:, }")
print()

documents = results['documents']
for index... ㅠㅠㅠ
for item in documents:
    print(f"제목: {item['title']}")
    print(f"저자: {item['authors']}")
    print(f"판매가: {item['sale_price']:,}")
    print(f"출판사: {item['publisher']}")
    print("-" * 50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 14
#      11 results = r.json() #json 형식
#      13 # =================================================================================
# ---> 14 print(f"검색개수: {results['meta']['total_count']:, }")
#      15 print()
#      17 documents = results['documents']
#
# ValueError: Cannot specify ',' with '\x20'.

# %%
# Kakao cafe 검색
import requests

url = "https://dapi.kakao.com/v2/search/cafe"

header = {"Authorization": "KakaoAK c699f3fbd5bb2b3f9be278dd0fb3e227"}
queryString = {'query': '파이썬', 'page':1, 'size':5}

r = requests.get(url, headers = header, params= queryString)
results = r.json() #json 형식
results
# Out:
# {'documents': [{'cafename': '코리아만세 [KOREAMANSE]',
#    'contents': '&lt;생성형AI 기반 풀스택 개발자 양성 (AI디자인·<b>파이썬</b>·리액트)&gt; 비전공자도 쉽고 재밌게 배우는 생성형 AI를 활용해서 만드는 풀스택개발자 취업과정! 🔎 개발자 취업...',
#    'datetime': '2025-11-04T11:23:33.000+09:00',
#    'thumbnail': '',
#    'title': 'AI활용 풀스택 개발자 양성(AI디자인, <b>파이썬</b>, 리액트)',
#    'url': 'https://cafe.daum.net/kimsangyoung/LQPn/2390'},
#   {'cafename': '두 드 림 연 구 소',
#    'contents': '3) https://www.onlinegdb.com/online_python_compiler 2. 오프라인 IDE 1) <b>파이썬</b>: https://<b>python</b>.org 2) 파이참: https://www.jetbrains.com/pycharm/ 3) Visual...',
#    'datetime': '2025-11-04T07:46:58.000+09:00',
#    'thumbnail': '',
#    'title': '3. <b>파이썬</b>',
#    'url': 'https://cafe.daum.net/ddlabkr/XpcN/108'},
#   {'cafename': '오라클자바교육센터 개발자를 위하여!',
#    'contents': '안녕하세요. 10월 마지막주 두번째 포스팅글 소개드립니다. <b>파이썬</b> 빅데이터분석 전문가 직무를 위한 취업훈련 단기심화 국비교육훈련 오라클자바교육학원은 미취업자...',
#    'datetime': '2025-10-29T16:55:08.000+09:00',
# ...
