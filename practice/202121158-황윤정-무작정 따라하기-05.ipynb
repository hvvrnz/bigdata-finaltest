# %% [markdown]
# <h3> 무작정 따라하기 -5</h3>

# %%
# 네이버 검색 API 예제 - 블로그 검색(XML)

import urllib.request

client_id = "Ybd64TtAhG6ixrzVWC9k"
client_secret = "nMPmQ56nI1"

encText = urllib.parse.quote("충주 맛집")
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# blog.json json 표기 없으면 default json 
url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

# 에러 안 난다는 가정 하에 예외처리 코드 삭제 
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
    
response_body = response.read() # source code 
print(response_body.decode('utf-8')) # 결과 출력시 디코딩 필요
# Out:
# <?xml version="1.0" encoding="UTF-8"?><rss version="2.0"><channel><title>Naver Open API - blog ::&apos;충주 맛집&apos;</title><link>https://search.naver.com</link><description>Naver Search Result</description><lastBuildDate>Sun, 09 Nov 2025 13:21:10 +0900</lastBuildDate><total>149621</total><start>1</start><display>10</display><item><title>장어와 샤브샤브까지 즐기는 &lt;b&gt;충주맛집&lt;/b&gt;, 명륜진사갈비 연수칠금점</title><link>https://blog.naver.com/rudtlsgus/224019147280</link><description>오늘 다녀온 곳은 충주에 위치한 명륜진사갈비입니다. 명륜진사갈비 연수칠금점 매일 11:30 - 22:00 21:30... &lt;b&gt;충주맛집&lt;/b&gt; 명륜진사갈비 연수칠금점의 고기zone~ 돼지갈비, 통삼겹살, 숯불닭갈비, 등갈비프렌치랙... </description><bloggername>토킹곰의 일상&amp;이슈 이야기</bloggername><bloggerlink>blog.naver.com/rudtlsgus</bloggerlink><postdate>20250923</postdate></item><item><title>[&lt;b&gt;충주맛집&lt;/b&gt;] 연수동 고깃집 선비한우고을</title><link>https://blog.naver.com/teriboss/224063021281</link><description>연수동 주민이라 청년축산 종종 애용하다가 협찬으로 청년축산에서 운영하는 &lt;b&gt;충주맛집&lt;/b&gt; 선비한우고을에... 충주고깃집 중에 우설주는곳이 있었는지 기억은안나는데 흔치 않
# ...

# %%
# 파싱하기

from bs4 import BeautifulSoup

soup = BeautifulSoup(response_body, "xml")
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
# 제목 추출

# %%
title = soup.find("title").text
title
# Out:
# "Naver Open API - blog ::'충주 맛집'"

# %%
# 날짜 추출 
date = soup.find("lastBuildDate").text
date
# Out:
# 'Sun, 09 Nov 2025 13:21:10 +0900'

# %%
# 총 검색 개수 추출 
total = int(soup.find("total").text)
print(f"{total:,}")
# Out:
# 149,621

# %%
# 검색 결과는 item 태그에

items = soup.find_all("item")
len(items)
# Out:
# 10

# %%
# 첫번째 검색 결과 확인
items[0]
# Out:
# <item><title>장어와 샤브샤브까지 즐기는 &lt;b&gt;충주맛집&lt;/b&gt;, 명륜진사갈비 연수칠금점</title><link>https://blog.naver.com/rudtlsgus/224019147280</link><description>오늘 다녀온 곳은 충주에 위치한 명륜진사갈비입니다. 명륜진사갈비 연수칠금점 매일 11:30 - 22:00 21:30... &lt;b&gt;충주맛집&lt;/b&gt; 명륜진사갈비 연수칠금점의 고기zone~ 돼지갈비, 통삼겹살, 숯불닭갈비, 등갈비프렌치랙... </description><bloggername>토킹곰의 일상&amp;이슈 이야기</bloggername><bloggerlink>blog.naver.com/rudtlsgus</bloggerlink><postdate>20250923</postdate></item>

# %%
# 모든 검색 결과 추출/출력
items = soup.find_all("item")

for item in items:
    print("제목:", item.find("title").text)
    print("블로거이름:", item.bloggername.text)
    print("-"*50)
# Out:
# 제목: 장어와 샤브샤브까지 즐기는 <b>충주맛집</b>, 명륜진사갈비 연수칠금점
# 블로거이름: 토킹곰의 일상&이슈 이야기
# --------------------------------------------------
# 제목: [<b>충주맛집</b>] 연수동 고깃집 선비한우고을
# 블로거이름: Eat Pray Love
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 곤드레 솥밥 한정식 마중(주차, 가격, 맛)
# 블로거이름: 잇츠젠의 열정과 감사의 공간
# --------------------------------------------------
# 제목: <b>충주맛집</b> 고메스퀘어 충주점 프리미엄뷔페
# 블로거이름: 원주중고차 합리적가격 영서자동차매매상사
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 입맛 없을 때 꼭 가야 하는 터줏골명가
# 블로거이름: 미진이야
# --------------------------------------------------
# 제목: <b>충주맛집</b>-가성비,맛,분위기 만족스런 고메스퀘어
# 블로거이름: 한농솔라파워
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 추천 충주갈비맛집은 우하하
# 블로거이름: 핑크순이의 렌즈를 통해 보는 세상
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 추천 가성비가 훌륭했던 카쿠레가 충주점
# 블로거이름: 화아타의 블로그
# --------------------------------------------------
# 제목: <b>충주 맛집</b>] 부드럽고 향긋한 100% 순메밀 막국수 맛집...
# 블로거이름: 바깥나날을 기록
# ...

# %%
# 네이버 검색 API 예제 - 블로그 검색(XML): 완성 코드

import urllib.request
from bs4 import BeautifulSoup

client_id = "Ybd64TtAhG6ixrzVWC9k"
client_secret = "nMPmQ56nI1"

# url 구성 및 검색 요청
encText = urllib.parse.quote("충주 맛집")
url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
response_body = response.read()

# 결과 추출
soup = BeautifulSoup(response_body, "xml")
items = soup.find_all("item")
for item in items:
    print("제목:", item.find("title").text)
    print("블로거이름:", item.bloggername.text)
    print("게시날짜:", item.find('postdate').text)
    print("-"*50)
# Out:
# 제목: 장어와 샤브샤브까지 즐기는 <b>충주맛집</b>, 명륜진사갈비 연수칠금점
# 블로거이름: 토킹곰의 일상&이슈 이야기
# 게시날짜: 20250923
# --------------------------------------------------
# 제목: [<b>충주맛집</b>] 연수동 고깃집 선비한우고을
# 블로거이름: Eat Pray Love
# 게시날짜: 20251103
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 곤드레 솥밥 한정식 마중(주차, 가격, 맛)
# 블로거이름: 잇츠젠의 열정과 감사의 공간
# 게시날짜: 20250903
# --------------------------------------------------
# 제목: <b>충주맛집</b> 고메스퀘어 충주점 프리미엄뷔페
# 블로거이름: 원주중고차 합리적가격 영서자동차매매상사
# 게시날짜: 20250330
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 입맛 없을 때 꼭 가야 하는 터줏골명가
# 블로거이름: 미진이야
# 게시날짜: 20250621
# --------------------------------------------------
# 제목: <b>충주맛집</b>-가성비,맛,분위기 만족스런 고메스퀘어
# 블로거이름: 한농솔라파워
# 게시날짜: 20251030
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 추천 충주갈비맛집은 우하하
# 블로거이름: 핑크순이의 렌즈를 통해 보는 세상
# 게시날짜: 20250910
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 추천 가성비가 훌륭했던 카쿠레가 충주점
# 블로거이름: 화아타의 블로그
# ...

# %%
# 네이버 검색 API 예제 - 블로그 검색(JSON)
import urllib.request

client_id = "Ybd64TtAhG6ixrzVWC9k"
client_secret = "nMPmQ56nI1"

encText = urllib.parse.quote("충주 맛집")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

# 요부분 수정
response_body = response.read()
print(response_body.decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Sun, 09 Nov 2025 13:25:32 +0900",
# 	"total":149621,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"장어와 샤브샤브까지 즐기는 <b>충주맛집<\/b>, 명륜진사갈비 연수칠금점",
# 			"link":"https:\/\/blog.naver.com\/rudtlsgus\/224019147280",
# 			"description":"오늘 다녀온 곳은 충주에 위치한 명륜진사갈비입니다. 명륜진사갈비 연수칠금점 매일 11:30 - 22:00 21:30... <b>충주맛집<\/b> 명륜진사갈비 연수칠금점의 고기zone~ 돼지갈비, 통삼겹살, 숯불닭갈비, 등갈비프렌치랙... ",
# 			"bloggername":"토킹곰의 일상&이슈 이야기",
# 			"bloggerlink":"blog.naver.com\/rudtlsgus",
# 			"postdate":"20250923"
# 		},
# 		{
# 			"title":"[<b>충주맛집<\/b>] 연수동 고깃집 선비한우고을",
# 			"link":"https:\/\/blog.naver.com\/teriboss\/224063021281",
# 			"description":"연수동 주민이라 청년축산 종종 애용하다가 협찬으로 청년축산에서 운영하는 <b>충주맛집<\/b> 선비한우고을에... 충주고깃집 중에 우설주는곳이 있었는지 기억은안나는데 흔치 않다고 생각하는데 우설까지... ",
# 			"bloggername":"Eat Pray Love",
# 			"bloggerlink":"blog.naver.com\/teriboss",
# 			"postdate":"20251103"
# 		},
# 		{
# 			"title":"<b>충주 맛집<\/b> 곤드레 솥밥 한정식 마중(주차, 가격, 맛)",
# ...

# %%
# json 결과를 딕셔너리로 변환
import json

results = json.loads(response_body)
print(type(response_body))
print(type(results))
# Out:
# <class 'bytes'>
# <class 'dict'>

# %%
# 딕셔너리 결과의 키 확인
results.keys()
# Out:
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
# 결과는 키 'items'에/첫번쨰 결과로 키 확인
items = results['items']
items[0]
# Out:
# {'title': '장어와 샤브샤브까지 즐기는 <b>충주맛집</b>, 명륜진사갈비 연수칠금점',
#  'link': 'https://blog.naver.com/rudtlsgus/224019147280',
#  'description': '오늘 다녀온 곳은 충주에 위치한 명륜진사갈비입니다. 명륜진사갈비 연수칠금점 매일 11:30 - 22:00 21:30... <b>충주맛집</b> 명륜진사갈비 연수칠금점의 고기zone~ 돼지갈비, 통삼겹살, 숯불닭갈비, 등갈비프렌치랙... ',
#  'bloggername': '토킹곰의 일상&이슈 이야기',
#  'bloggerlink': 'blog.naver.com/rudtlsgus',
#  'postdate': '20250923'}

# %%
# 결과 추출
for item in items:
    print("제목:", item['title'])
    print("게시날짜:", item['postdate'])
    print("-"*50)
# Out:
# 제목: 장어와 샤브샤브까지 즐기는 <b>충주맛집</b>, 명륜진사갈비 연수칠금점
# 게시날짜: 20250923
# --------------------------------------------------
# 제목: [<b>충주맛집</b>] 연수동 고깃집 선비한우고을
# 게시날짜: 20251103
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 곤드레 솥밥 한정식 마중(주차, 가격, 맛)
# 게시날짜: 20250903
# --------------------------------------------------
# 제목: <b>충주맛집</b> 고메스퀘어 충주점 프리미엄뷔페
# 게시날짜: 20250330
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 입맛 없을 때 꼭 가야 하는 터줏골명가
# 게시날짜: 20250621
# --------------------------------------------------
# 제목: <b>충주맛집</b>-가성비,맛,분위기 만족스런 고메스퀘어
# 게시날짜: 20251030
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 추천 충주갈비맛집은 우하하
# 게시날짜: 20250910
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 추천 가성비가 훌륭했던 카쿠레가 충주점
# 게시날짜: 20250826
# --------------------------------------------------
# 제목: <b>충주 맛집</b>] 부드럽고 향긋한 100% 순메밀 막국수 맛집...
# 게시날짜: 20250630
# --------------------------------------------------
# ...

# %%
# 네이버 검색 API 예제 - 블로그 검색(JSON): 완성 코드
import urllib.request
import json

client_id = "Ybd64TtAhG6ixrzVWC9k"
client_secret = "nMPmQ56nI1"

encText = urllib.parse.quote("충주 맛집")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
response_body = response.read()

# 결과 추출
results = json.loads(response_body)
items = results['items']
for item in items:
    print("제목:", item['title'])
    print("게시날짜:", item['postdate'])
    print("-"*50)
# Out:
# 제목: 장어와 샤브샤브까지 즐기는 <b>충주맛집</b>, 명륜진사갈비 연수칠금점
# 게시날짜: 20250923
# --------------------------------------------------
# 제목: [<b>충주맛집</b>] 연수동 고깃집 선비한우고을
# 게시날짜: 20251103
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 곤드레 솥밥 한정식 마중(주차, 가격, 맛)
# 게시날짜: 20250903
# --------------------------------------------------
# 제목: <b>충주맛집</b> 고메스퀘어 충주점 프리미엄뷔페
# 게시날짜: 20250330
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 입맛 없을 때 꼭 가야 하는 터줏골명가
# 게시날짜: 20250621
# --------------------------------------------------
# 제목: <b>충주맛집</b>-가성비,맛,분위기 만족스런 고메스퀘어
# 게시날짜: 20251030
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 추천 충주갈비맛집은 우하하
# 게시날짜: 20250910
# --------------------------------------------------
# 제목: <b>충주 맛집</b> 추천 가성비가 훌륭했던 카쿠레가 충주점
# 게시날짜: 20250826
# --------------------------------------------------
# 제목: <b>충주 맛집</b>] 부드럽고 향긋한 100% 순메밀 막국수 맛집...
# 게시날짜: 20250630
# --------------------------------------------------
# ...

# %%
# 한글 인코딩
import urllib.request

encText = urllib.parse.quote("건국대글로컬")
print(encText)
# Out:
# %EA%B1%B4%EA%B5%AD%EB%8C%80%EA%B8%80%EB%A1%9C%EC%BB%AC

# %%
# 네이버 검색 API 예제 - 블로그 검색(JSON)
# 옵션 추가

import urllib.request
import json

client_id = "Ybd64TtAhG6ixrzVWC9k"
client_secret = "nMPmQ56nI1"

# 검색어 및 옵션 지정
encText = urllib.parse.quote("공주 맛집")
url = "https://openapi.naver.com/v1/search/blog?query=" 
url += encText 
url += "&display=5&start=1&sort=sim"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

response_body = response.read()
results = json.loads(response_body)
items = results["items"]

for item in items:    
   print("제목:", item['title'])    
   print("게시날짜:", item['postdate'])    
   print("-"*50)
# Out:
# 제목: 동학사돈금정 점심 먹으러 가기에도 좋은 <b>공주맛집</b>
# 게시날짜: 20251017
# --------------------------------------------------
# 제목: <b>공주 맛집</b> 한식 밥꽃하나피었네 가족외식 후기
# 게시날짜: 20251103
# --------------------------------------------------
# 제목: 으뜸<b>공주맛집</b> 시골인심 가득 담은 한정식 공주 유구읍 도연정
# 게시날짜: 20251003
# --------------------------------------------------
# 제목: <b>공주 맛집</b> 추천 고가네칼국수 제민천 근처 현지인 맛집
# 게시날짜: 20251017
# --------------------------------------------------
# 제목: <b>공주 맛집</b> 한식 밥꽃하나피었네 블루리본 식당
# 게시날짜: 20251107
# --------------------------------------------------

# %%
# 네이버 검색 API 예제 - 책 검색(JSON)
# 옵션 추가

import urllib.request
import json

client_id = "Ybd64TtAhG6ixrzVWC9k"
client_secret = "nMPmQ56nI1"

encText = urllib.parse.quote("파이썬 스크래핑")
url = "https://openapi.naver.com/v1/search/book.json?query=" 
url += encText 
url += "&display=5&start=1&sort=sim"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

response_body = response.read()
results = json.loads(response_body)

items = results['items']
items[0]
# Out:
# {'title': '파이썬 웹 스크래핑 (다양한 상황 해결을 통한 웹 스크랩)',
#  'link': 'https://search.shopping.naver.com/book/catalog/32496619771',
#  'image': 'https://shopping-phinf.pstatic.net/main_3249661/32496619771.20220527052042.jpg',
#  'author': '리차드 로손',
#  'discount': '0',
#  'publisher': '에이콘출판',
#  'pubdate': '20170427',
#  'isbn': '9788960779594',
#  'description': '[파이썬 웹 스크래핑]은 웹 스크랩의 기본 개념과 파이썬 3를 이용해 쉽고 빠르게 웹 스크래핑하는 방법을 알려준다. 웹사이트를 다운로드해 정규식을 통해서 스크랩하는 방식부터 파이썬 라이브러리(Scrapy, Selenium)까지 점차 개념을 확장해나가 기초를 다질 수 있다. 여러 상황을 고려한 예제로 기본 원리를 테스트할 수 있으며, 배운 방법을 실제 서비스를 제공하는 웹사이트에 적용하는 방법도 배울 수 있다.'}

# %%
items = results["items"]

for item in items:
    print(f"제목: {item['title']}")
    print(f"저자: {item['author']}")
    print(f"출판사: {item['publisher']}")
    print(f"가격: {int(item['discount']):,}")
    print(f"출판일: {item['pubdate']}")
    print("-"*50)
# Out:
# 제목: 파이썬 웹 스크래핑 (다양한 상황 해결을 통한 웹 스크랩)
# 저자: 리차드 로손
# 출판사: 에이콘출판
# 가격: 0
# 출판일: 20170427
# --------------------------------------------------
# 제목: 파이썬 웹 스크래핑 2/e (수많은 데이터 사이에서 필요한 정보 수집하기)
# 저자: 캐서린 자멀^리차드 로손
# 출판사: 에이콘출판
# 가격: 22,500
# 출판일: 20181231
# --------------------------------------------------
# 제목: 파이썬(Python) 2학년 스크래핑의 구조 (체험으로 배우고! 대화 형식으로 공부!)
# 저자: 모리 요시나오
# 출판사: 성안당
# 가격: 15,300
# 출판일: 20211117
# --------------------------------------------------
# 제목: 실무에 바로 적용하는 AI 대비 파이썬 기초 입문서 (파이썬 기초부터 웹스크래핑, 통계 실무, 데이터 분류, 예측, 객체 탐지까지)
# 저자: 강봉주
# 출판사: 자유아카데미
# 가격: 31,280
# 출판일: 20230303
# --------------------------------------------------

# %%
# 다음 책 검색

import requests
import json

url = "https://dapi.kakao.com/v3/search/book"

header = {"Authorization": "KakaoAK c699f3fbd5bb2b3f9be278dd0fb3e227"}
queryString = {'query': '빅데이터기초', 'page':1, 'size':5}

r = requests.get(url, headers = header, params= queryString)
results = json.loads(r.text)   # 딕셔너리로 변환
results
# Out:
# {'documents': [{'authors': ['토마스 얼', 'Wajid Khattak', 'Paul Buhler'],
#    'contents': '『빅데이터 기초』는 빅데이터를 매우 실무적 차원에서 접근한 도서이다. 무엇보다 이론적인 기술보다는 기업에서 빅데이터에 왜 관심이 있는지, 어떠한 비즈니스 문제를 해결하는 데 도움이 되는지, 이를 위해 기업은 전략적, 전술적, 오퍼레이션적 관점에서 무엇을 해야 하는지, 그리고 탑 매니저, 현업 부서, IT 부서 각자의 역할과 책임은 무엇인지에 대해 1, 2, 3, 4장에서 상세히 기술하였다.',
#    'datetime': '2017-09-05T00:00:00.000+09:00',
#    'isbn': '8968669775 9788968669774',
#    'price': 18000,
#    'publisher': '시그마프레스',
#    'sale_price': 17460,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F946369%3Ftimestamp%3D20240124170900',
#    'title': '빅데이터 기초',
#    'translators': ['조성준'],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=946369&q=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0+%EA%B8%B0%EC%B4%88'},
#   {'authors': ['김권현'],
# ...

# %%
# meta 확인

results['meta']
# Out:
# {'is_end': False, 'pageable_count': 42, 'total_count': 42}

# %%
# 결과는 documents에

documents = results['documents']
documents[0]
# Out:
# {'authors': ['토마스 얼', 'Wajid Khattak', 'Paul Buhler'],
#  'contents': '『빅데이터 기초』는 빅데이터를 매우 실무적 차원에서 접근한 도서이다. 무엇보다 이론적인 기술보다는 기업에서 빅데이터에 왜 관심이 있는지, 어떠한 비즈니스 문제를 해결하는 데 도움이 되는지, 이를 위해 기업은 전략적, 전술적, 오퍼레이션적 관점에서 무엇을 해야 하는지, 그리고 탑 매니저, 현업 부서, IT 부서 각자의 역할과 책임은 무엇인지에 대해 1, 2, 3, 4장에서 상세히 기술하였다.',
#  'datetime': '2017-09-05T00:00:00.000+09:00',
#  'isbn': '8968669775 9788968669774',
#  'price': 18000,
#  'publisher': '시그마프레스',
#  'sale_price': 17460,
#  'status': '정상판매',
#  'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F946369%3Ftimestamp%3D20240124170900',
#  'title': '빅데이터 기초',
#  'translators': ['조성준'],
#  'url': 'https://search.daum.net/search?w=bookpage&bookId=946369&q=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0+%EA%B8%B0%EC%B4%88'}

# %%
# 결과 추출
documents = results['documents']

for item in documents:
    print(f"제목: {item['title']}")
    print(f"저자: {item['authors']}")
    print(f"출판사: {item['publisher']}")
    print(f"가격: {item['price']:,}")
    print(f"출판일: {item['datetime']}")
    print("-"*50)
# Out:
# 제목: 빅데이터 기초
# 저자: ['토마스 얼', 'Wajid Khattak', 'Paul Buhler']
# 출판사: 시그마프레스
# 가격: 18,000
# 출판일: 2017-09-05T00:00:00.000+09:00
# --------------------------------------------------
# 제목: R로 하는 빅데이터 분석: 데이터 전처리와 시각화
# 저자: ['김권현']
# 출판사: 숨은원리
# 가격: 25,000
# 출판일: 2019-03-01T00:00:00.000+09:00
# --------------------------------------------------
# 제목: 최고효과 기초탄탄 계산법. 10(초등 5학년)
# 저자: ['기탄교육 연구소']
# 출판사: 기탄교육
# 가격: 7,000
# 출판일: 2017-02-08T00:00:00.000+09:00
# --------------------------------------------------
# 제목: 빅토익 파트(Part)7 기초
# 저자: ['켈리 최', '시원스쿨 영어연구소', '신승호', '박상신', '윤서연', '홍지영']
# 출판사: 시원스쿨닷컴
# 가격: 16,000
# 출판일: 2017-11-20T00:00:00.000+09:00
# --------------------------------------------------
# 제목: R로 하는 빅데이터 분석: 데이터 전처리와 시각화(개정판)
# 저자: ['김권현']
# 출판사: 숨은원리
# 가격: 25,000
# 출판일: 2020-01-14T00:00:00.000+09:00
# --------------------------------------------------

# %%
# 다음 블로그 검색

import requests
import json

url = "https://dapi.kakao.com/v2/search/blog"

header = {"Authorization": "KakaoAK c699f3fbd5bb2b3f9be278dd0fb3e227"}
queryString = {'query': '충주', 'page':1, 'size':5}

r = requests.get(url, headers = header, params= queryString)
results = json.loads(r.text)   # 딕셔너리로 변환

documents = results['documents']

for item in documents:
    print(f"제목: {item['title']}")
    print(f"설명: {item['contents']}")
    print(f"게시일: {item['datetime']}")
    print("-"*50)
# Out:
# 제목: <b>충주</b>파스타맛집 볼라레
# 설명: #<b>충주</b>볼라레 <b>충주</b>파스타맛집​ 볼라레​ 글 / 사진 / 영상 memorynote <b>충주</b>파스타맛집 볼라레는 <b>충주</b>이탈리안레스토랑이에요. 25년 경력의 셰프님께서 만드시는 다양한 토마토 파스타와 크림 파스타가 있고 쫄깃하면서도 바삭한 피자가 있어 아이들과 함께 또는 <b>충주</b> 데이트 맛집으로도 좋아요. 노지 캠핑장 산책로가 있어서...
# 게시일: 2025-11-06T13:04:00.000+09:00
# --------------------------------------------------
# 제목: <b>충주</b> 아쿠아리움 솔직 후기입니다
# 설명: ​ 안녕하세요 불친절한희준씨 입니다. ​ 오늘의 후기는 지난주 토요일에 개장한 <b>충주</b> 아쿠아리움에 다녀온 리뷰 입니다 최대한 있는 그대로 솔직히 작성할게요 ​ ​ <b>충주</b> 아쿠아리움 글/사진 : 불친절한희준씨 ​ 입장료 : 연말까지 무료 주소 : 충북 <b>충주</b>시 옻갓길 73-1 위치 : <b>충주</b> 탄금공원 제2주차장과 가까워요 영업시간...
# 게시일: 2025-10-28T16:58:00.000+09:00
# --------------------------------------------------
# 제목: <b>충주</b> 게으른악어 카페
# 설명: ​ ​ <b>충주</b> 게으른악어 카페 다녀온 후기 가을 캠핑 감성까지 ​ 글/사진/여행광녀 ​ ​ ​ ​ <b>충주</b> 악어봉 가을 산행을 마치고, 오후 햇살이 부드럽게 내려앉을 무렵, 우리는 <b>충주</b> 게으른악어 카페로 발걸음을 옮겼습니다. 바람이 포근했고, 호수를 따라 번지는 노을빛이 참 예뻤습니다. 야외 데크에서 라면을 끓여 먹는 소소한 재미...
# 게시일: 2025-11-03T08:12:00.000+09:00
# ...
